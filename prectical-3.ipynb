# %%
#to split an array of 14 elements into 3 arrays, each with 2, 4,
#and 8 elements in the original order
#216270307051
#Grishma m. Jethva

import numpy as np

a=np.arange(1,15)
b=np.split(a,(2,6))
print(a)
print(b)

# %%
# to stack arrays horizontally (column wise)
#216270307051
#Grishma m. Jethva

import numpy as np
a=np.array([1,2,3,4,5])
b=np.array([6,7,8,9,10])
print(a)
c=np.hstack((a,b))
print(c)
